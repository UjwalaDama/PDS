# %%
#student_fratility_test
#plotting
#question1
#preprocessing_data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snsfrom
from scipy import stats

# %%
from plotly.tools import FigureFactory as FF

# %%
r_data=pd.read_csv('/content/Frailty_raw_data.csv')

# %%
r_data
# Out:
#    Height (Inches)  Weight (Pounds)   Age  Grip strength Frailty
# 0             65.8               112   30             30       N
# 1             71.5               136   19             31       N
# 2             69.4               153   45             29       N
# 3             68.2               142   22             28       Y
# 4             67.8               144   29             24       Y
# 5             68.7               123   50             26       N
# 6             69.8               141   51             22       Y
# 7             70.1               136   23             20       Y
# 8             67.9               112   17             19       N
# 9             66.8               120   39             31       N

# %%
##Preprocessing the data to perform the analysis

# %%
#analysing the column names with the related units of measure
r_data.columns=['Height(in)', 'Weight(lb)', 'Age', 'Grip_strength(kg)','Frailty']
r_data.columns

# Changing the categorical values into numerical class values
r_data['Frailty'].replace(['Y', 'N'],
                        [0, 1], inplace=True)

# %%
clean_data=r_data.dropna()
clean_data
# Out:
#    Height(in)  Weight(lb)  Age  Grip_strength(kg)  Frailty
# 0        65.8         112   30                 30        1
# 1        71.5         136   19                 31        1
# 2        69.4         153   45                 29        1
# 3        68.2         142   22                 28        0
# 4        67.8         144   29                 24        0
# 5        68.7         123   50                 26        1
# 6        69.8         141   51                 22        0
# 7        70.1         136   23                 20        0
# 8        67.9         112   17                 19        1
# 9        66.8         120   39                 31        1

# %%
df.to_csv("C:/Users/Administrator/Desktop/Principles_of_data_science_Assignment-1/Question_1_Fraility_project/data_clean/Cleaned_Fraility_data.csv", index=False)

# %%
clean_data.to_csv('/content/clean_data.csv')
print('successfully saved the data')
# Out:
# successfully saved the data
